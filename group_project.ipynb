# %%
import pandas as pd
import numpy as np

# %%
location = "C:/Users/GBTC408009ur/Documents/sj_advance data analytics/Final Project/import_expenditures_on_health.xlsx"
health_df = pd.read_excel(location)

# %%
health_df.head()
# Out:
#                Data_Type  Region_Country_Area_Code Region_Country_Area_Name  \
# 0  Expenditure on health                         4              Afghanistan
# 1  Expenditure on health                         4              Afghanistan
# 2  Expenditure on health                         4              Afghanistan
# 3  Expenditure on health                         4              Afghanistan
# 4  Expenditure on health                         4              Afghanistan
#
#    Year                                 Series    Value Footnotes  \
# 0  2005  Current health expenditure (% of GDP)   9.9483       NaN
# 1  2010  Current health expenditure (% of GDP)   8.5697       NaN
# 2  2014  Current health expenditure (% of GDP)   9.5289       NaN
# 3  2015  Current health expenditure (% of GDP)  10.0940       NaN
# 4  2016  Current health expenditure (% of GDP)  10.1987       NaN
#
#                                               Source
# 0  World Health Organization (WHO), Geneva, WHO G...
# ...

# %%
location2 = "C:/Users/GBTC408009ur/Documents/sj_advance data analytics/Final Project/import_populationgrowth.xlsx"
population_df = pd.read_excel(location2)

# %%
population_df.head()
# Out:
#                                            Data_Type  \
# 0  Population growth and indicators of fertility ...
# 1  Population growth and indicators of fertility ...
# 2  Population growth and indicators of fertility ...
# 3  Population growth and indicators of fertility ...
# 4  Population growth and indicators of fertility ...
#
#    Region_Country_Area_Code       Region_Country_Area_Name  Year  \
# 0                         1  Total, all countries or areas  2005
# 1                         1  Total, all countries or areas  2005
# 2                         1  Total, all countries or areas  2005
# 3                         1  Total, all countries or areas  2005
# 4                         1  Total, all countries or areas  2005
#
#                                               Series  Value  \
# 0       Population annual rate of increase (percent)    1.3
# 1          Total fertility rate (children per women)    2.6
# 2  Infant mortality for both sexes (per 1,000 liv...   49.1
# ...

# %%
population_df.shape
# Out:
# (4978, 8)

# %%
#show the column names in the dataset
population_df.columns
# Out:
# Index(['Data_Type', 'Region_Country_Area_Code', 'Region_Country_Area_Name',
#        'Year', 'Series', 'Value', 'Footnotes', 'Source'],
#       dtype='object')

# %%
#number of non-NA values
#len(df) would count rows including NA values
population_df.count()
# Out:
# Data_Type                   4978
# Region_Country_Area_Code    4978
# Region_Country_Area_Name    4978
# Year                        4978
# Series                      4978
# Value                       4978
# Footnotes                   4319
# Source                      4978
# dtype: int64

# %%
#New data frame without foot note & source
new_df = pd.DataFrame(data = population_df, columns=['Region_Country_Area_Code','Region_Country_Area_Name','Year','Series','Value'])

# %%
#making sure no missing data
new_df.count()
# Out:
# Region_Country_Area_Code    4978
# Region_Country_Area_Name    4978
# Year                        4978
# Series                      4978
# Value                       4978
# dtype: int64

# %%
new_df.head()
# Out:
#    Region_Country_Area_Code       Region_Country_Area_Name  Year  \
# 0                         1  Total, all countries or areas  2005
# 1                         1  Total, all countries or areas  2005
# 2                         1  Total, all countries or areas  2005
# 3                         1  Total, all countries or areas  2005
# 4                         1  Total, all countries or areas  2005
#
#                                               Series  Value
# 0       Population annual rate of increase (percent)    1.3
# 1          Total fertility rate (children per women)    2.6
# 2  Infant mortality for both sexes (per 1,000 liv...   49.1
# 3  Maternal mortality ratio (deaths per 100,000 p...  288.0
# 4    Life expectancy at birth for both sexes (years)   67.2

# %%
#Changing column headers
new_df.columns = ['Region_code', 'Region_name', 'Year', 'Series', 'Value']

# %%
new_df.head()
# Out:
#    Region_code                    Region_name  Year  \
# 0            1  Total, all countries or areas  2005
# 1            1  Total, all countries or areas  2005
# 2            1  Total, all countries or areas  2005
# 3            1  Total, all countries or areas  2005
# 4            1  Total, all countries or areas  2005
#
#                                               Series  Value
# 0       Population annual rate of increase (percent)    1.3
# 1          Total fertility rate (children per women)    2.6
# 2  Infant mortality for both sexes (per 1,000 liv...   49.1
# 3  Maternal mortality ratio (deaths per 100,000 p...  288.0
# 4    Life expectancy at birth for both sexes (years)   67.2

# %%
regions = [1,2,15,202,14, 16, 17, 18, 11, 19, 419, 29, 13, 5, 3, 21, 142, 143, 30, 35, 34, 145, 150, 
           151, 154, 39, 155, 9, 53, 54, 57,61, 62, 136, 830]
region_df = new_df[new_df['Region_code'].isin(regions) ]
country_df = new_df[~new_df['Region_code'].isin(regions) ]

# %%
region_df
# Out:
#       Region_code                    Region_name  Year  \
# 0               1  Total, all countries or areas  2005
# 1               1  Total, all countries or areas  2005
# 2               1  Total, all countries or areas  2005
# 3               1  Total, all countries or areas  2005
# 4               1  Total, all countries or areas  2005
# 5               1  Total, all countries or areas  2005
# 6               1  Total, all countries or areas  2005
# 7               1  Total, all countries or areas  2010
# 8               1  Total, all countries or areas  2010
# 9               1  Total, all countries or areas  2010
# 10              1  Total, all countries or areas  2010
# 11              1  Total, all countries or areas  2010
# 12              1  Total, all countries or areas  2010
# 13              1  Total, all countries or areas  2010
# 14              1  Total, all countries or areas  2015
# 15              1  Total, all countries or areas  2015
# ...

# %%
#Saving to excel
writer = pd.ExcelWriter('region_df.xlsx', engine='xlsxwriter')
region_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
#Saving to excel after spliting
writer = pd.ExcelWriter('country_df.xlsx', engine='xlsxwriter')
country_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
#finds rows where the region code represents regions and doesn't represent countries
#Isolating countries from regions
#new_df.loc[df['Region_code'] == 1 or ] 
regions = [1,2,15,202,14,17, 18, 11, 19, 419, 29, 13, 5, 3, 21, 142, 143, 30, 35, 34, 145, 150, 
           151, 154, 39, 155, 9, 53, 54, 57,61]
#country_df = new_df.loc[df['Region_code'] not in regions 
for region in regions:
    for ind in new_df.index: 
        if new_df['Region_code'][ind] == region:
            new_df.loc[new_df['Region_code'] == region , 'Region_code'] =0

# %%
new_df.describe
# Out:
# <bound method NDFrame.describe of       Region_code                    Region_name  Year  \
# 0               1  Total, all countries or areas  2005
# 1               1  Total, all countries or areas  2005
# 2               1  Total, all countries or areas  2005
# 3               1  Total, all countries or areas  2005
# 4               1  Total, all countries or areas  2005
# 5               1  Total, all countries or areas  2005
# 6               1  Total, all countries or areas  2005
# 7               1  Total, all countries or areas  2010
# 8               1  Total, all countries or areas  2010
# 9               1  Total, all countries or areas  2010
# 10              1  Total, all countries or areas  2010
# 11              1  Total, all countries or areas  2010
# 12              1  Total, all countries or areas  2010
# 13              1  Total, all countries or areas  2010
# 14              1  Total, all countries or areas  2015
# ...

# %%
new_df
# Out:
#       Region_code                    Region_name  Year  \
# 0               1  Total, all countries or areas  2005
# 1               1  Total, all countries or areas  2005
# 2               1  Total, all countries or areas  2005
# 3               1  Total, all countries or areas  2005
# 4               1  Total, all countries or areas  2005
# 5               1  Total, all countries or areas  2005
# 6               1  Total, all countries or areas  2005
# 7               1  Total, all countries or areas  2010
# 8               1  Total, all countries or areas  2010
# 9               1  Total, all countries or areas  2010
# 10              1  Total, all countries or areas  2010
# 11              1  Total, all countries or areas  2010
# 12              1  Total, all countries or areas  2010
# 13              1  Total, all countries or areas  2010
# 14              1  Total, all countries or areas  2015
# 15              1  Total, all countries or areas  2015
# ...

# %%
country_df.head()
# Out:
#      Region_code  Region_name  Year  \
# 564            4  Afghanistan  2005
# 565            4  Afghanistan  2005
# 566            4  Afghanistan  2005
# 567            4  Afghanistan  2005
# 568            4  Afghanistan  2005
#
#                                                 Series  Value
# 564       Population annual rate of increase (percent)    4.4
# 565          Total fertility rate (children per women)    7.2
# 566  Infant mortality for both sexes (per 1,000 liv...   89.5
# 567  Maternal mortality ratio (deaths per 100,000 p...  821.0
# 568    Life expectancy at birth for both sexes (years)   56.9

# %%
region_df.head(10)
# Out:
#    Region_code                    Region_name  Year  \
# 0            1  Total, all countries or areas  2005
# 1            1  Total, all countries or areas  2005
# 2            1  Total, all countries or areas  2005
# 3            1  Total, all countries or areas  2005
# 4            1  Total, all countries or areas  2005
# 5            1  Total, all countries or areas  2005
# 6            1  Total, all countries or areas  2005
# 7            1  Total, all countries or areas  2010
# 8            1  Total, all countries or areas  2010
# 9            1  Total, all countries or areas  2010
#
#                                               Series  Value
# 0       Population annual rate of increase (percent)    1.3
# 1          Total fertility rate (children per women)    2.6
# 2  Infant mortality for both sexes (per 1,000 liv...   49.1
# 3  Maternal mortality ratio (deaths per 100,000 p...  288.0
# 4    Life expectancy at birth for both sexes (years)   67.2
# ...

# %%
new_df.head(17)
# Out:
#     Region_code                    Region_name  Year  \
# 0             1  Total, all countries or areas  2005
# 1             1  Total, all countries or areas  2005
# 2             1  Total, all countries or areas  2005
# 3             1  Total, all countries or areas  2005
# 4             1  Total, all countries or areas  2005
# 5             1  Total, all countries or areas  2005
# 6             1  Total, all countries or areas  2005
# 7             1  Total, all countries or areas  2010
# 8             1  Total, all countries or areas  2010
# 9             1  Total, all countries or areas  2010
# 10            1  Total, all countries or areas  2010
# 11            1  Total, all countries or areas  2010
# 12            1  Total, all countries or areas  2010
# 13            1  Total, all countries or areas  2010
# 14            1  Total, all countries or areas  2015
# 15            1  Total, all countries or areas  2015
# 16            1  Total, all countries or areas  2015
#
# ...

# %%
#unique values in a column
x = print(len(new_df['Region_code'].unique()))
# Out:
# 263

# %%
#health_chper_df = health_df.loc[(health_df['Series'] == 'Current health expenditure (% of GDP)')]
new_region_df = new_df.loc[(new_df['Series'] == 'Population annual rate of increase (percent)')]

# %%
new_region_df.head()
# Out:
#     Region_code                    Region_name  Year  \
# 0             1  Total, all countries or areas  2005
# 7             1  Total, all countries or areas  2010
# 14            1  Total, all countries or areas  2015
# 21            2                         Africa  2005
# 27            2                         Africa  2010
#
#                                           Series  Value
# 0   Population annual rate of increase (percent)    1.3
# 7   Population annual rate of increase (percent)    1.2
# 14  Population annual rate of increase (percent)    1.2
# 21  Population annual rate of increase (percent)    2.5
# 27  Population annual rate of increase (percent)    2.5

# %%
#Convert Series column into different columns to work with data
pivotTableDF = pd.pivot_table(new_df,
                              index=('Region_code','Year'),
                              columns='Series',
                              values='Value',
                              margins=True)

# pd.pivot_table(df, values='Value', index=['RegionCode', 'RegionName','Year'], columns=['Series'])

# %%
pivotTableDF.head()
# Out:
# Series            Infant mortality for both sexes (per 1,000 live births)  \
# Region_code Year
# 1           2005                                               49.1
#             2010                                               41.3
#             2015                                               35.0
# 2           2005                                               80.7
#             2010                                               68.1
#
# Series            Life expectancy at birth for both sexes (years)  \
# Region_code Year
# 1           2005                                             67.2
#             2010                                             69.1
#             2015                                             70.8
# 2           2005                                             53.7
#             2010                                             57.0
#
# Series            Life expectancy at birth for females (years)  \
# Region_code Year
# ...

# %%
df = pivotTableDF

# %%
df.describe()
# Out:
# Series  Infant mortality for both sexes (per 1,000 live births)  \
# count                                          703.000000
# mean                                            30.631624
# std                                             27.498111
# min                                              1.600000
# 25%                                              8.150000
# 50%                                             20.500000
# 75%                                             49.050000
# max                                            134.900000
#
# Series  Life expectancy at birth for both sexes (years)  \
# count                                        706.000000
# mean                                          69.592057
# std                                            9.104119
# min                                           41.300000
# 25%                                           64.200000
# 50%                                           72.050000
# ...

# %%
df
# Out:
# Series            Infant mortality for both sexes (per 1,000 live births)  \
# Region_code Year
# 1           2005                                          49.100000
#             2010                                          41.300000
#             2015                                          35.000000
# 2           2005                                          80.700000
#             2010                                          68.100000
#             2015                                          57.200000
# 4           2005                                          89.500000
#             2010                                          76.700000
#             2015                                          68.600000
# 5           2005                                          25.500000
#             2010                                          20.300000
#             2015                                          17.100000
# ...

# %%
#Resetting pivot table back to dataframe
df1 = pivotTableDF.reset_index()

# %%
df1.head()
# Out:
# Series Region_code  Year  \
# 0                1  2005
# 1                1  2010
# 2                1  2015
# 3                2  2005
# 4                2  2010
#
# Series  Infant mortality for both sexes (per 1,000 live births)  \
# 0                                                    49.1
# 1                                                    41.3
# 2                                                    35.0
# 3                                                    80.7
# 4                                                    68.1
#
# Series  Life expectancy at birth for both sexes (years)  \
# 0                                                  67.2
# 1                                                  69.1
# 2                                                  70.8
# 3                                                  53.7
# 4                                                  57.0
#
# Series  Life expectancy at birth for females (years)  \
# ...

# %%
df1.describe()
# Out:
# Series  Infant mortality for both sexes (per 1,000 live births)  \
# count                                          703.000000
# mean                                            30.631624
# std                                             27.498111
# min                                              1.600000
# 25%                                              8.150000
# 50%                                             20.500000
# 75%                                             49.050000
# max                                            134.900000
#
# Series  Life expectancy at birth for both sexes (years)  \
# count                                        706.000000
# mean                                          69.592057
# std                                            9.104119
# min                                           41.300000
# 25%                                           64.200000
# 50%                                           72.050000
# ...

# %%
df1
# Out:
# Series Region_code  Year  \
# 0                1  2005
# 1                1  2010
# 2                1  2015
# 3                2  2005
# 4                2  2010
# 5                2  2015
# 6                4  2005
# 7                4  2010
# 8                4  2015
# 9                5  2005
# 10               5  2010
# 11               5  2015
# 12               8  2005
# 13               8  2010
# 14               8  2015
# 15               9  2005
# 16               9  2010
# 17               9  2015
# 18              11  2005
# 19              11  2010
# 20              11  2015
# 21              12  2005
# 22              12  2010
# 23              12  2015
# 24              13  2005
# 25              13  2010
# 26              13  2015
# 27              14  2005
# 28              14  2010
# 29              14  2015
# ..             ...   ...
# 809            850  2010
# 810            850  2015
# 811            854  2005
# 812            854  2010
# ...

# %%
df1.describe()
# Out:
# Series  Infant mortality for both sexes (per 1,000 live births)  \
# count                                          703.000000
# mean                                            30.631624
# std                                             27.498111
# min                                              1.600000
# 25%                                              8.150000
# 50%                                             20.500000
# 75%                                             49.050000
# max                                            134.900000
#
# Series  Life expectancy at birth for both sexes (years)  \
# count                                        706.000000
# mean                                          69.592057
# std                                            9.104119
# min                                           41.300000
# 25%                                           64.200000
# 50%                                           72.050000
# ...

# %%
#drop a column
df1.drop('All', axis=1)
# Out:
# Series Region_code  Year  \
# 0                1  2005
# 1                1  2010
# 2                1  2015
# 3                2  2005
# 4                2  2010
# 5                2  2015
# 6                4  2005
# 7                4  2010
# 8                4  2015
# 9                5  2005
# 10               5  2010
# 11               5  2015
# 12               8  2005
# 13               8  2010
# 14               8  2015
# 15               9  2005
# 16               9  2010
# 17               9  2015
# 18              11  2005
# 19              11  2010
# 20              11  2015
# 21              12  2005
# 22              12  2010
# 23              12  2015
# 24              13  2005
# 25              13  2010
# 26              13  2015
# 27              14  2005
# 28              14  2010
# 29              14  2015
# ..             ...   ...
# 809            850  2010
# 810            850  2015
# 811            854  2005
# 812            854  2010
# ...

# %%
#Saving to excel, dataframe after pivoting
writer = pd.ExcelWriter('population_df.xlsx', engine='xlsxwriter')
df1.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
location = "C:/Users/GBTC408009ur/Documents/sj_advance data analytics/Final Project/pop_exp.xlsx"
pop_exp_df = pd.read_excel(location)
#C:\Users\GBTC408009ur\Documents\sj_advance data analytics\Final Project

# %%
pop_exp_df.head()
# Out:
#    Region_Country_Area_Code Region_Country_Area_Name  Year  Cur_health_exp  \
# 0                         4              Afghanistan  2005          9.9483
# 1                         4              Afghanistan  2010          8.5697
# 2                         4              Afghanistan  2015         10.0940
# 3                         8                  Albania  2005          6.3428
# 4                         8                  Albania  2010          5.0100
#
#    dom_gen_govern_health_exp  pop_annl_increase  tot_fertil_rate  \
# 0                     3.3710                4.4              7.2
# 1                     2.2555                2.8              6.4
# 2                     2.0144                3.2              5.3
# 3                     9.6865               -0.3              1.9
# 4                     8.4640               -0.9              1.6
#
#    infant_mortal  maternal_mortal  life_expect_both_sexes  life_expect_males  \
# ...

# %%
#Descriptive stats for population and expenditure
pop_exp_df.describe()
# Out:
#        Region_Country_Area_Code         Year  Cur_health_exp  \
# count                696.000000   696.000000      696.000000
# mean                 441.206897  2010.000000        5.248764
# std                  250.694943     4.085419        3.643740
# min                    4.000000  2005.000000        0.000000
# 25%                  229.750000  2005.000000        2.958275
# 50%                  441.000000  2010.000000        5.292650
# 75%                  659.250000  2015.000000        7.500400
# max                  894.000000  2015.000000       26.288900
#
#        dom_gen_govern_health_exp  pop_annl_increase  tot_fertil_rate  \
# count                 696.000000         696.000000       696.000000
# mean                    8.017535           1.379023         2.633908
# std                     5.882507           1.572495         1.748002
# min                     0.000000          -5.000000         0.000000
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#make a scatterplot of GDP expenditure vs life expectancy
sns.lmplot(x='Cur_health_exp', y='life_expect_both_sexes', data=pop_exp_df)

# %%
#make a scatterplot of Govt expenditure vs life expectancy
sns.lmplot(x='dom_gen_govern_health_exp', y='life_expect_both_sexes', data=pop_exp_df)

# %%
#use this library to build a statistical test for linear regression
import statsmodels.formula.api as smf

# %%
#OLS is Ordinary Least Squares, the most common type of linear regression
#the fit function uses the predictive values to calculate the best linear regression line
result = smf.ols('dom_gen_govern_health_exp ~ life_expect_both_sexes', data=pop_exp_df).fit()

# %%
#the summary will show the calculated values (slopes and y-intercept) for the linear regression formula
#the closer to 1 the r-squared value is, the better the fit of the linear regression line
#the p-value shows how statistically significant a predictive feature could be the model

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     dom_gen_govern_health_exp   R-squared:                       0.123
# Model:                                   OLS   Adj. R-squared:                  0.121
# Method:                        Least Squares   F-statistic:                     96.95
# Date:                       Fri, 23 Aug 2019   Prob (F-statistic):           1.69e-21
# Time:                               12:34:59   Log-Likelihood:                -2174.9
# No. Observations:                        696   AIC:                             4354.
# Df Residuals:                            694   BIC:                             4363.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ...
